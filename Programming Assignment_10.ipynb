# %% [markdown]
# #**PROGRAMMING ASSIGNMENT_10**

# %% [markdown]
# **1. Write a Python program to find sum of elements in list?**

# %%
# Python program to find the sum of elements in list
list1 = [15, 8, 65, 74, 32, 60]

def sumele(l):
  sum1 = 0
  for i in l:
    sum1 = sum1 + i
  return sum1

print(f"The sum of elements in list is {sumele(list1)}.")
# Out:
# The sum of elements in list is 254.

# %%
# By using sum in built function
list1 = [15, 8, 65, 74, 32, 60]

print(f"The sum of elements in list is {sum(list1)}.")
# Out:
# The sum of elements in list is 254.

# %% [markdown]
# **2. Write a Python program to Multiply all numbers in the list?**

# %%
# Python program to multiply all numbers in the list

list1 = [15, 8, 65, 74, 32, 60]

def muloflist(l):
  mul1 = 1
  for i in list1:
    mul1 = mul1*i
  return mul1

print(f"The multiply all numbers in the list is {muloflist(list1)}.")
# Out:
# The multiply all numbers in the list is 1108224000.

# %%
from functools import reduce
l2 = [15, 8, 65, 74, 32, 60]
result = reduce((lambda x, y: x*y), l2)
print(f"The multiply all numbers in the list is {result}.")
# Out:
# The multiply all numbers in the list is 1108224000.

# %% [markdown]
# **3. Write a Python program to find smallest number in a list?**

# %%
# Python program to find smallest number in a list
l2 = [15, 8, 65, 74, 32, 60]

def minele(l):
  a = l[0]
  for i in range(len(l)):
    if l[i] < l[0]:
      l[0] = l[i]
  return l[0]

print(f"The smallest number in a list is {minele(l2)}.")
# Out:
# The smallest number in a list is 8.

# %%
# Sorting the list in ascending order

l2 = [15, 8, 65, 74, 32, 60]

l2.sort()

print(f"The smallest number in a list is {l2[0]}.")
# Out:
# The smallest number in a list is 8.

# %%
# sorting the list in descending order

l2 = [15, 8, 65, 74, 32, 60]

l2.sort(reverse = True)

print(f"The smallest number in a list is {l2[-1]}.")
# Out:
# The smallest number in a list is 8.

# %%
# By using inbuilt function
l2 = [15, 8, 65, 74, 32, 60]
print(f"The smallest number in a list is {min(l2)}.")
# Out:
# The smallest number in a list is 8.

# %%
# By user defined element

l4 = []

n = int(input("Enter the number of elements is: "))

for i in range(1, n+1):
  ele = int(input("Enter the element is: "))
  l4.append(ele)

print(f"The smallest number in a list is {min(l4)}.")
# Out:
# Enter the number of elements is: 5
# Enter the element is: 10
# Enter the element is: 15
# Enter the element is: 20
# Enter the element is: 25
# Enter the element is: 30
# The smallest number in a list is 10.

# %% [markdown]
# **4. Write a Python program to find largest number in a list?**

# %%
# Python program to find the largest number in a list
l2 = [15, 8, 65, 74, 32, 60]

b = l2[0]

for i in range(len(l2)):
  if l2[i] > l2[0]:
    l2[0] = l2[i]

print(f"The largest number in a list is {l2[0]}.")
# Out:
# The largest number in a list is 74.

# %%
# Sorting the list in ascending order
l2 = [15, 8, 65, 74, 32, 60]
l2.sort()
print(f"The largest number in a list is {l2[-1]}")
# Out:
# The largest number in a list is 74

# %%
# sorting the list in descending order
l2 = [15, 8, 65, 74, 32, 60]
l2.sort(reverse = True)
print(f"The largest number in a list is {l2[0]}.")
# Out:
# The largest number in a list is 74.

# %%
# By using the inbuilt function max
l2 = [15, 8, 65, 74, 32, 60]
print(f"The largest number in a list is {max(l2)}.")
# Out:
# The largest number in a list is 74.

# %%
# By user defined 

l5 = []

n = int(input("Enter the number of elements: "))

for i in range(1, n+1):
  ele = int(input("Enter the element is: "))
  l5.append(ele)

print(f"The largest number in a list is {max(l5)}.")
# Out:
# Enter the number of elements: 5
# Enter the element is:  25
# Enter the element is: 8
# Enter the element is: 79
# Enter the element is: 84
# Enter the element is: 56
# The largest number in a list is 84.

# %% [markdown]
# **5. Write a Python program to find second largest number in a list?**

# %%
# Python program to find second largest number in a list

list1 = [10, 20, 20, 4, 45, 45, 45, 99, 99]

# remove the duplicates from the list
list1 = list(set(list1))

# sort the list
list1.sort()

# print
print(f"The second largest number in a list is {list1[-2]}.")
# Out:
# The second largest number in a list is 45.

# %%
list1 = [10, 20, 20, 4, 45, 45, 45, 99, 99]

# remove the duplicates from the list
new_list = list(set(list1))

# remove the max element from the list
new_list.remove(max(new_list))

# Display
print(f"The second largest number in a list is {max(new_list)}.")
# Out:
# The second largest number in a list is 45.

# %% [markdown]
# **6. Write a Python program to find N largest elements from a list?**

# %%
# Python program to find N Largest elements from a list

def Nmaxelements(list1, N):
  final_list = []

  for i in range(0, N):
    max1 = 0

    for j in range(len(list1)):
      if list1[j] > max1:
        max1 = list1[j]

    list1.remove(max1)
    final_list.append(max1)
  print(final_list)

list1 = [2, 6, 41, 85, 0, 3, 7, 6, 10]
N = 2

Nmaxelements(list1, N)
# Out:
# [85, 41]

# %%
l = [2, 6, 41, 85, 0, 3, 7, 6, 10]
n = 4
l.sort()
print(f"The N largest elements from the list is {l[-n:]}.")
# Out:
# The N largest elements from the list is [7, 10, 41, 85].

# %% [markdown]
# **7. Write a Python program to print even numbers in a list?**

# %%
l = [2, 6, 41, 85, 0, 3, 7, 6, 10]
l1 = []
for i in l:
  if i % 2 == 0:
    l1.append(i)
print(l1)
# Out:
# [2, 6, 0, 6, 10]

# %% [markdown]
# **8. Write a Python program to print odd numbers in a List?**

# %%
l = [2, 6, 41, 85, 0, 3, 7, 6, 10]
l1 = []

for i in l:
  if i % 2!= 0:
    l1.append(i)
print(l1)
# Out:
# [41, 85, 3, 7]

# %% [markdown]
# **9. Write a Python program to Remove empty List from List?**

# %%
list1 = [[], [], [], "Red", "Green", [1, 2], "Blue", [], []]

print("Original list:")
print(list1)
print("\nAfter deleting the empty lists from the given list:")
list2 = [x for x in list1 if x]
print(list2)
# Out:
# Original list:
# [[], [], [], 'Red', 'Green', [1, 2], 'Blue', [], []]
#
# After deleting the empty lists from the given list:
# ['Red', 'Green', [1, 2], 'Blue']

# %% [markdown]
# **10. Write a Python program to Cloning or Copying a list?**

# %%
# Python program to clonning or copying a list

def cloning(li1):
  li_copy = li1
  return li_copy

l = [2, 6, 41, 85, 0, 3, 7, 6, 10]
l1 = cloning(l)
print(f"The copying a list is {l1}")
# Out:
# The copying a list is [2, 6, 41, 85, 0, 3, 7, 6, 10]

# %% [markdown]
# **11. Write a Python program to Count occurrences of an element in a list?**

# %%
# Python program to count occurances of an element in a list

def countofele(l, ele):
  count = 0
  for i in l:
    if ele == i:
      count = count + 1
  return count

list1 = [10, 20, 20, 4, 45, 45, 45, 99, 99]
ele = 45
print(f"The occurances of an element in a list is {countofele(list1, ele)}")
# Out:
# The occurances of an element in a list is 3
