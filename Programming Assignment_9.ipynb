# %% [markdown]
# #**PROGRAMMING ASSIGNMENT_9**

# %% [markdown]
# **1. Write a Python program to check if the given number is a Disarium Number?**
# - A number is said to be the Disarium number when the sum of its digit raised to the power of their respective positions becomes equal to the number itself.
#
# - for example, 175 is a Disarium number as follows:
# $1^1 + 7^2 + 5^3 = 1 + 49 + 125 = 175$

# %%
# Python program to check if the given number is a Disarium Number

def calculateLength(n):
  length = 0;
  while(n != 0):
    length = length + 1
    n = n//10
  return length


num = 175
rem = sum = 0
len = calculateLength(num)

# Makes a copy of the original number num
n = num;

# calculates the sum of digits powered with their respective position
while(num > 0):
  rem = num % 10
  sum = sum + int(rem**len)
  num = num // 10
  len = len - 1

# chekcks whether the sum is equal to the number iteself
if (sum == n):
  print(f"The given number{n} is a disarium number.")
else:
  print(f"The given number{n} is not disarium number.")
# Out:
# The given number175 is a disarium number.

# %% [markdown]
# **2. Write a Python program to print all disarium numbers between 1 to 100?**

# %%
# Python program to print all disarium numbers between 1 to 100

# calculate length() will count the digits present in a number
def calculateLength(n):
  length = 0
  while(n!=0):
    length = length + 1
    n = n//10
  return length

# sum of digits() will calculates the sum of digits powered with their respective position

def sumofdigits(num):
  rem = sum = 0
  len = calculateLength(num)


  while(num > 0):
    rem = num%10
    sum = sum + (rem**len)
    num = num//10
    len = len - 1
  return sum

result = 0

# display all disarium numbers between 1 to 100
print("Disarium numbers between 1 and 100 are: ")

for i in range(1, 101):
  result = sumofdigits(i)

  if result == i:
    print(i, end=" ")
# Out:
# Disarium numbers between 1 and 100 are:
# 1 2 3 4 5 6 7 8 9 89

# %% [markdown]
# **3. Write a Python program to check if the given number is Happy Number?**
# - A happy number is defined by the following process:
#
#   Starting with any positive integer, replace the number by the sum of the squares of its digits, and repeat the process until the number equals 1(where it will stay, or it loops endlessely in a cycle which does not include 1, Those numbers for which this process ends in 1 are happy numbers, while those that do not end in 1 are unhappy numbers.
#
# ![image.png](data:image/png;base64,...)

# %%
def is_happy_num(n):
  past = set()
  while n != 1:
    n = sum(int(i)**2 for i in str(n))

    if n in past:
      return False
    past.add(n)
  return True

print(f"The given num is {is_happy_num(7)}.")
print(f"The given num is {is_happy_num(932)}.")
print(f"The given num is {is_happy_num(6)}.")
# Out:
# The given num is True.
# The given num is True.
# The given num is False.

# %% [markdown]
# **4. Write a Python program to print all happy numbers between 1 and 100?**

# %%
def is_happy_num(num):
  rem = sum = 0

  # calculates the sum of squares of digits
  while(num > 0):
    rem = num%10
    sum = sum + (rem*rem)
    num = num//10
  return sum

# Display all happy numbers between 1 to 100
print("List of happy numbers between 1 to 100 are: ")
for i in range(1, 101):
  result = i

  # Happy number always ends with 1

  while(result != 1 and result != 4):
    result = is_happy_num(result)

  if result == 1:
    print(i, end = " ")
# Out:
# List of happy numbers between 1 to 100 are:
# 1 7 10 13 19 23 28 31 32 44 49 68 70 79 82 86 91 94 97 100

# %% [markdown]
# **5. Write a Python program to determine whether the given number is a Harshad Number?**
# - If a number is divisible by the sum of its digits, then it will be known as a Harshad Number.
# For example: The number 156 is divisible by the sum(12) of its digits (1, 5, 6).

# %%
num = 156
rem = sum = 0

# make a copy of num and store it in variable n

n = num

# calculates sum of digits
while(num > 0):
  rem = num % 10
  sum = sum + rem
  num = num//10

# checks whether the number is divisible by the sum of digits
if (n % sum == 0):
  print(f"The given number{num} is a Harshad Number.")
else:
  print(f"The given number{num} is not a Harshad Number.")
# Out:
# The given number0 is a Harshad Number.

# %% [markdown]
# **6. Write a Python program to print all pronic numbers between 1 and 100?**
# - The pronic number is a product of two consecutive integers of the form : $n(n+1)$
# - for example:
#
# $6 = 2(2+1) = n(n+1)$
#
# $72 = 8(8+1) = n(n+1)$

# %%
# Python program to print all pronic numbers between 1 and 100

def is_pronic_num(num):
  flag = False

  for j in range(1, num + 1):
    #checks for pronic number by multiplying consecutive numbers
    if ((j * (j + 1)) == num):
      flag = True
      break
  return flag

# display pronic numbers between 1 to 100
print("Pronic numbers between 1 and 100 are: ")
for i in range(1, 101):
  if (is_pronic_num(i)):
    print(i, end = " ")
# Out:
# Pronic numbers between 1 and 100 are:
# 2 6 12 20 30 42 56 72 90
